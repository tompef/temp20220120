# %% [markdown]
# <a href="https://colab.research.google.com/github/tompef/temp20220120/blob/main/TDP_001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Too Easy!!!

# %%
#100 / 25

print ('this is the beginners class')
# Out:
# this is the beginners class

# %%
100 / 25
# Out:
# 4.0

# %%
import pandas as pd
content = pd.read_csv('/content/sample_data/tdp_data.csv')

df0 = pd.DataFrame(content,columns=['SECTION_ID', 'DZZ', 'UPDATE_DT', 'RANKER'])
df1 = df0.drop_duplicates(subset = ["SECTION_ID"])
df2 = df1["SECTION_ID"]
  
for x in df2:
    #print(x)
    df3 = df0.drop_duplicates(subset = ["RANKER"])[df0['SECTION_ID']==x]
    df4 = df3["RANKER"]
    
    for x1 in df4:
        #print (x1)
        RowX = df0[(df0['SECTION_ID']==x) & (df0['RANKER']==x1)]   
        RowXX = RowX[(RowX["DZZ"])!=0]
        print(RowXX)
    
    #print("x")
# Out:
# <ipython-input-7-008fc4248012>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df3 = df0.drop_duplicates(subset = ["RANKER"])[df0['SECTION_ID']==x]
# Empty DataFrame
# Columns: [SECTION_ID, DZZ, UPDATE_DT, RANKER]
# Index: []
# Empty DataFrame
# Columns: [SECTION_ID, DZZ, UPDATE_DT, RANKER]
# Index: []
# Empty DataFrame
# Columns: [SECTION_ID, DZZ, UPDATE_DT, RANKER]
# Index: []
# Empty DataFrame
# Columns: [SECTION_ID, DZZ, UPDATE_DT, RANKER]
# Index: []
# Empty DataFrame
# Columns: [SECTION_ID, DZZ, UPDATE_DT, RANKER]
# Index: []
# Empty DataFrame
# Columns: [SECTION_ID, DZZ, UPDATE_DT, RANKER]
# Index: []
# Empty DataFrame
# Columns: [SECTION_ID, DZZ, UPDATE_DT, RANKER]
# Index: []
# Empty DataFrame
# Columns: [SECTION_ID, DZZ, UPDATE_DT, RANKER]
# Index: []
# Empty DataFrame
# Columns: [SECTION_ID, DZZ, UPDATE_DT, RANKER]
# Index: []
# Empty DataFrame
# Columns: [SECTION_ID, DZZ, UPDATE_DT, RANKER]
# Index: []
# Empty DataFrame
# ...
